# %% [markdown]
# #### Special Character Removal

# %%
import re

# input string
input_str = "hello how are$ you!!"

# Using regular expressions to remove special characters
clean_str = re.sub(r"[^a-zA-Z0-9\s]","",input_str)

print(clean_str)
# Out:
# hello how are you

# %%
import re

# input string
input_str = "hello123 how are$ you!!"

# Using regular expressions to remove special characters
clean_str = re.sub(r"[^a-zA-Z0-9\s]","",input_str)

print(clean_str)
# Out:
# hello123 how are you

# %% [markdown]
# ## Libraries in the field of NLP
#
# - SpaCy - Natural Langage Processing library in python that can be used to tokenize and process textual data
# - nltk

# %%
import spacy
 
# Load the spacy model
nlp = spacy.load("en_core_web_sm")

# Input string
input_str = "hello how are$ you !! "

# Function to clean the string
def clean_text(text):
    cleaned_text = ''.join(char for char in text if char.isalpha() or char.isspace())
    doc = nlp(cleaned_text)
    return ' '.join(token.text for token in doc)

# Get the final output
clean_str = clean_text(input_str)
print(clean_str)
# Out:
# hello how are you

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')

input_str = "hello how are$ you !! "

tokens = nltk.word_tokenize(input_str)

# Remove the special characters
clean_tokens = [token for token in tokens if token.isalnum()]

clean_str = ' '.join(clean_tokens)

print(clean_str)
# Out:
# hello how are you
# [nltk_data] Downloading package punkt to C:\Users\Jatin
# [nltk_data]     Dhiman\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Jatin
# [nltk_data]     Dhiman\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
