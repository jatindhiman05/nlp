# %%
import contractions

text = "I'm happy because I can't attend. It's okay."

expanded = contractions.fix(text)

print(expanded)
# Out:
# I am happy because I cannot attend. It is okay.

# %%
import re

def expand_contractions(text):
    contractions_pattern = {
        r"(?i)can't":"cannot",
        r"(?i)won't":"will not",
        r"(?i)it's":"it is",
        r"(?i)weren't":"were not",
        r"(?i)I'm":"I am" 
    }
    for contraction, expansion in contractions_pattern.items():
        text = re.sub(contraction, expansion, text)

    return text

txt = "I can't believe it's already raining"
expanded_text = expand_contractions(txt)
print(expanded_text)
# Out:
# I cannot believe it is already raining
